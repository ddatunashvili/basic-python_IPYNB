# %%
'კეთილი მანტიორი'
'''
გაყოფისას დეფოლტად იძლევა Float ტიპის ობიექტს
მთელიც და წილადი ნაწილიც
'''
6/3
# Out:
# 2.0

# %%
'''
გაყოფისას დეფოლტად იძლევა Int ტიპის ობიექტს
მხოლოდ მთელი ნაწილი
'''
6//2
# Out:
# 3

# %%
'''
ხარისხში აყვანა
'''
2**2
# Out:
# 4

# %%
'''
გამოიტანს მხოლოდ ნაშთს
'''
3 % 2
# Out:
# 1

# %%
'''
a % b = a - (  (b//a) *b )
# Explained
2.5 % 1.5 = 2.5 -2.5 // 1.5 * 1.5
= 2.5 - (1.0) * 1.5 
= 2.5 - (1.0)
= 1
'''
2.5 %  1.5
# Out:
# 1.0

# %%
'''
2 + ( (2/2) * ( 2**(2+2) )
# Eplained
2 + 2/2*2**(2+2)
= 2 + (1) * 2 **(4) ჯერ ფრჩხილი და მერე გაყოფა 
= 2 + (2)**4  მერე გამრავლება
= 2 + (2*2*2*2) მერე ხარისხი
= 2 + (16) ჯამი
= 18
არ დაგვავიწყდეს Float ტიპს გამოიტანს
'''
2 + 2/2*2**(2+2)
# Out:
# 18.0

# %%
'''
lambda ფუნქციაში შეგიძლია შეიყვანო პარამეტრი, რომელიც
ძალიან გამოსადეგია მრავალჯერადი გამოყენებისათვის.
გამოირჩევა სიმარტივით.
'''
# გამოიყენე ლამბდა ფუნქცია
კვადრატში_აიყვანე = lambda x: x**2
კვადრატში_აიყვანე(5)
# Out:
# 25

# %%
'დავალება'
'''
1. ყველა ოპერაციაა მინიჭებების გარდა, რომელსაც გავივლით შემდეგში :)
2. ამოხსნილი მაქვს ზევით და აღწერილი
3. კვადრატში_აიყვანე = lambda x: x**2 ______როცა შემოვა x აიყვანე კვადრატში
   კვადრატში_აიყვანე(5)  ____ კვადრატში_აიყვანეში შეიტანე 
'''
# 4. ორი რიცხვის კვადრატების ჯამს
a = float(input('შეიყვანე პირველი რიცხვი: '))
b = float(input('შეიყვანე მეორე რიცხვი : '))
f = a**2+b**2
print(f)
