# %%
'კეთილი მანტიორი'
'''
syntax: კომენტარი დახურე ხოლმე
# კომენტარის არასწორი ვარიანტი
"""
print("Hello Students!")
print("My name is Konstantin.")
print("I like Python.")
#------------------------------
'''
# კომენტარის სწორი ვარიანტი
"""
print("Hello Students!")
print("My name is Konstantin.")
print("I like Python.")
"""
# Out:
# '\nprint("Hello Students!")\nprint("My name is Konstantin.")\nprint("I like Python.")\n'

# %%
'''
syntax: (რა გინდა ვერ გამიგია) # მარჯვნივ გაუქმებით ფუნქციას ნუ მიფუჭებ
print(#" Hello Students! ")
'''
print(" Hello Students! ")

# %%
'დავალება'
# 1. 
print("Hello Students!") # დაბეჭდე მისალმება
# დაბეჭდე მე მომწონს პითონი
print("I like Python.")
"""
პითონი ადვილია
"""
# დაბეჭდე მოდი ერთად ვეცადოთ სწავლა
print("Let's try to learn it together!")
'''
2. ახსნილი მაქვს ზევით
3. მოყვანილი მაქვს ზევით
'''
# 3. კომენტარის შეცდომა

'''
syntax: სამ ბრჭყალიანი კომენტარი რომ გაიღო აღარ დაიხურა 
"""
print('ტესტი')
""
'''
# Out:
# Hello Students!
# I like Python.
# Let's try to learn it together!
# '\nsyntax: სამ ბრჭყალიანი კომენტარი რომ გაიღო აღარ დაიხურა \n"""\nprint(\'ტესტი\')\n""\n'
