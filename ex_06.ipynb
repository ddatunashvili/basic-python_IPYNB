# %%
# ივანიშვილის ხუმრობა
აფეთქება = 'ადრე ჭიათურაში მაღაროებს აფეთქებდნენ' # აფეთქების ამბავი
ქალი = 'არვარ იმნაირი!!  ' # ქალის სიწყვა
გამვლელი = 'შედი ქალო ბუტკაში!! ' # გამვლელის სიტყვები
# გამოიტანე აფეთქება და გამვლელის სიტყვები
print(f"{აფეთქება} და ერთ-ერთი გამვლელი ეუბნება ქალს {გამვლელი} {გამვლელი}")
# გამოიტანე ქალის პასუხი
print(f"პასუხობს ქალი: {ქალი * 2 } ")
# მიანიჭე გამვლელს ახალი სიტყვა
გამვლელი = 'რანაირიც გინდა იყავი აფეთქებაა არდაიღუპოო'
# გამოიტანე გამვლელის ახალი სიტყვა
print(f"გამვლელი : {გამვლელი} ")
# მიანიჭე ქალის სიტყვა
x = f'მე ვთქვი: {ქალი}'
# მიანიჭე გამვლელის სიტყვა
y = f'მე ვთქვი: {გამვლელი}'
# გამოიტანე მინიჭებული ქალის სიტყვა
print(x)
# გამოიტანე მინიჭებული გამვლელის სიტყვა
print(y)
# ხუმრობას მიანიჭე ხუმრობის შემოწმების კითხვა
ხუმრობა = 'სასაცილოა? '
# არასასაცილო ხუმრობას მიანიჭე  რეაქციის შემოწმების კითხვა და ჩასასმელი ადგილი
არა_სასაცილო = 'რატო გეცინება ?! {}'
# ჩასვი ხუმრობა არასასაცილოს შემოწმებაში ხუმრობის შემოწმების კითხვა
print(არა_სასაცილო.format(ხუმრობა))
# Out:
# ადრე ჭიათურაში მაღაროებს აფეთქებდნენ და ერთ-ერთი გამვლელი ეუბნება ქალს შედი ქალო ბუტკაში!!  შედი ქალო ბუტკაში!!
# პასუხობს ქალი: არვარ იმნაირი!!  არვარ იმნაირი!!
# გამვლელი : რანაირიც გინდა იყავი აფეთქებაა არდაიღუპოო
# მე ვთქვი: არვარ იმნაირი!!
# მე ვთქვი: რანაირიც გინდა იყავი აფეთქებაა არდაიღუპოო
# რატო გეცინება ?! სასაცილოა?

# %%
'კეთილი მანტიორი'
'''
index: რომ მეუბნები {} {} {}, უნდა მომცე 3 ცვლადი
და {} ცარიელს ნუ მიტოვებ
--------------------------------------------
ხუმრობა = 'ეს სასაცილოა? '
არა_სასაცილო = 'რატო გეცინება ?! {} {} {}'
print(არა_სასაცილო.format(ხუმრობა,ხუმრობა))
'''
ხუმრობა = 'ეს სასაცილოა? '
არა_სასაცილო = 'რატო გეცინება ?! {} {} {}'
print(არა_სასაცილო.format(ხუმრობა,ხუმრობა,ხუმრობა,ხუმრობა))
# Out:
# რატო გეცინება ?! ეს სასაცილოა?  ეს სასაცილოა?  ეს სასაცილოა?

# %%
'''
მე: ( ვაძლევ 3 ცვლადს, 1 {} ში)
პითონი: რაც მეკუთვნის იმდენს ვიღებ, 
დანარჩენი არმჭირდება შენთვის დაიტოვე
'''
ხუმრობა = 'ეს სასაცილოა? '
არა_სასაცილო = 'რატო გეცინება ?! {} '
print(არა_სასაცილო.format(ხუმრობა,ხუმრობა,ხუმრობა))
# Out:
# რატო გეცინება ?! ეს სასაცილოა?

# %%
'დავალება'
'''
1. კომენტარები მივუწერე 
2. 8 შემთხვევაა (y = f"Those who know {binary} and those who {do_not}."), print(f"I said: {x}"), print(f"I also said: '{y}'")
,print(greetings.format(konstantin)), print(greetings.format(Ashur)),
print(greetings.format(Kakha)), print(f"Hello {Konstantin}!")
print(f"Hello {Ashur}!"), print(f"Hello {Kakha}!")
3. კი იტყუები 
4. ის აერთიანებს ორ სტრინგს  და ჩააბავს,ჩაამატებს სტრინგში
"დათო" + "დათუნაშვილი" = "დათოდათუნაშვილი"
'''
# ცვლადი რომელიშიც არის სტრინგები 'დათო' ,' ', 'დათუნაშვილი'
სახელი_გვარი = "დათო "+' '+ "დათუნაშვილი"
print(სახელი_გვარი)
# არის 'დათო' ცვლად სახელი_გვარი ში?
print('დათო' in სახელი_გვარი)
# არის ' ' ცვლად სახელი_გვარი ში?
print('' in სახელი_გვარი)
# არის 'დათუნაშვილი' ცვლად სახელი_გვარი ში?
print('დათუნაშვილი' in სახელი_გვარი)
#-----------------------------------------------
# ცვლადს სახელს მიანიჭე სტრინგი  'დათო' 
სახელი = 'დათო' 
# ცვლადს გვარს მიანიჭე სტრინგი  'დათუნაშვილი'
გვარი = 'დათუნაშვილი'
# ცვლადი რომელშიც არის სტრინგი და სტრინგში ("ველიუს შესატანი ბოქსები")
სახელი_გვარი = "ჩემი სახელია {} და გვარია {}"
# შეიტანე ცვლადები და ისე გამოიტანე ცვლადი სახელი_გვარი
print(სახელი_გვარი.format(სახელი,გვარი))
# გამოიტანე სახელი_გვარის ცვლადი
print(სახელი_გვარი) # აქ იგივე დარჩა და არ ჩაემატა სტრინგები
# Out:
# დათო  დათუნაშვილი
# True
# True
# True
# ჩემი სახელია დათო და გვარია დათუნაშვილი
# ჩემი სახელია {} და გვარია {}
