# %%
'პროგრამის დაწერის წესები'
# if ბრძანების წესები
'''
1. ყველა if სჭირდება else.
2. თუ else არ გჭირდება ჯობია die ფუნქცია ჩაწერო,
რომელიც შეცდომას ამოაგდებს და გააჩერებს
3. if ბრძანების რამდენიმე დონით დაწერას შეეშვი
ორზე მეტი დონე არ არის რეკომენდირებული
4. ყოველ if elif else დაყავით და ერთ ხაზზე არ დაწეროთ
5. ლოგიკური გამოსახულებები მარტივი უნდა იყოს და ცვლადებით მიაწოდეთ
კალკულაციები
'''
# ციკლის წესები
'''
1. გამოიყენეთ while ციკლი სამუდამო ციკლებისთვის მხოლოდ.
2. for ციკლი გამოიყენეთ თუ ხშირად დაგჭირდებათ მისი გამოყენება
'''
# დებაგინგის რჩევები
'''
1. დებაგერს შეეშვი!
2. დებაგინგი print(), გაიგებ ცვლილების ეტაპებს
3. ყურადღება მიაქციეთ, რომ ყველა ნაწილი სწორად ეწეროს
"პატარა კოდი დაწერე და ცოტა-ცოტა შეასწორე"
4. უკუ დებაგინგი
'ჯობია კოდს უკუღმა მიჰყვე თუ ვერ პოულობ შეცდომას'
'''
# Out:
# '\n1. დებაგერს შეეშვი!\n2. დებაგინგი print(), გაიგებ ცვლილების ეტაპებს\n3. ყურადღება მიაქციეთ, რომ ყველა ნაწილი სწორად ეწეროს\n"პატარა კოდი დაწერე და ცოტა-ცოტა შეასწორე"\n4. უკუ დებაგინგი\n\'ჯობია კოდს უკუღმა მიჰყვე თუ ვერ პოულობ შეცდომას\'\n'
