# %%
# make it stop saying!! :)
print("Hello Students!")
print("My name is Konstantin.")
print("I like Python.")
print("Python is easy!")
print('Hooray!')
print("Let's try to learn it together!")
# Out:
# Hello Students!
# My name is Konstantin.
# I like Python.
# Python is easy!
# Hooray!
# Let's try to learn it together!

# %%
# არვიცოდი ეს უნდა გადამეკეთებინა თუ არა და ალტერნატივა შევქმენი
#----------------------------------------------------------------
# ლექტორს მიესალმე
print("გამარჯობა ბატონო კონსტანტინ!")
# ჩემი თავი წარუდგინე
print("ჩემი სახელია დავითი.")
# ესეც უთხარი ბარემ
print("ჩემთვის სასიამოვნოა პითონში მუშაობა.")
# უთხარი ჩვენი ურთიერთობის შესახებ
print("ძალიან მარტივია!")
# უთხარი ჩემი შენდამი დამოკიდებულება
print('ძალიან მაგარია!!!!')
# უთხარი შენგან რას მოველი
print("მინდა საფუძვლიანად შევისწავლო თქვენთან.")
# Out:
# გამარჯობა ბატონო კონსტანტინ!
# ჩემი სახელია დავითი.
# ჩემთვის სასიამოვნოა პითონში მუშაობა.
# ძალიან მარტივია!
# ძალიან მაგარია!!!!
# მინდა საფუძვლიანად შევისწავლო თქვენთან.

# %%
' კეთილი მანტიორი :)'
#----------------------------------------------------------------
''' 
syntax: სტრიქონი უნდა დახურო
print ("Hello Students!) 
'''
print("Hello Students! ")
# Out:
# Hello Students!

# %%
'''
syntax: სტრიქონი არუნდა გაწყვიტო
print("Hello
      Students!")
'''
print("Hello",
      "Students!")
# Out:
# Hello Students!

# %%
'''
indentation:  შეწეული აბზაცი ვერ გავიგე (მეორე დონეზეა, შეწეულია)
print("Hello Students!")
    print("My name is Konstantin.")
'''
print("Hello Students!")
print("My name is Konstntin.")
# Out:
# Hello Students!
# My name is Konstntin.

# %%
'''
syntax: " " გახსნა/დახურვას  არასწორად იყენებ
print(""Hello Students!"")
'''
print(""'Hello Students!'"")
# Out:
# Hello Students!

# %%
#  " " შორის ტექსტი გამოიტანე ( გახსნა/დახურა " ")
print("'Hello Students!'")
#-------------------------------------------
#  ' ' შორის ტექსტი გამოიტანე  ( გახსნა/დახურა " ")
print('"Hello Students!"')
# Out:
# 'Hello Students!'
# "Hello Students!"

# %%
# <>  ლამაზი ტონით წერე   <>
#-------------------------------------------
'''
თუ სიტყვაა იყენებ ' '       მარტივი ცვლადი
თუ წინადადებაა იყენებ " "   რთული ცვლადი
'''
# remember
print("კოდი არის შექმნილი, რომ კომენტარები გააგებინოს 'დებილ' კომპიუტერს .")
print('თუ სახალისო "ელემენტს" მოაშორებ, მოსაწყენია კოდის წერა :) .')
# Out:
# კოდი არის შექმნილი, რომ კომენტარები გააგებინოს 'დებილ' კომპიუტერს .
# თუ სახალისო "ელემენტს" მოაშორებ, მოსაწყენია კოდის წერა :) .

# %%
'დავალება'
# 1. 
"დავით დათუნაშვილი"
'''
2. ზევით მაქვს ახსნილი
'''
# 3 
print('პირველი სტრიქონი')
# print('მეორე სტრიქონი')
'''
4. მესამეში გამოვიყენე სტრიქონის მარჯვენა მხარის გასათიშად
კომენტარია და არ კითხულობს 
'''
# Out:
# 'დავით დათუნაშვილი'
