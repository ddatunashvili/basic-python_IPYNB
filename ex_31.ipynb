# %%
'გადაწყვეტილების მიღება'
'''
ფერმერმა მდინარეზე უნდა გადაიყვანოს მგელი,
ცხვარი და ერთი კომბოსტო, მაგრამ მას მხოლოდ ერთი ნავი აქვს, 
რომელშიც მხოლოდ ერთი ადამიანი და კიდევ ერთი რამ შეიძლება მოთავსდეს – ან მგელი, 
ან ცხვარი ან კომბოსტო.გასათვალისწინებელია ის, 
რომ ფერმერი ერთ ნაპირზე ვერ დატოვებს ერთად მგელს და ცხვარს, 
რადგანაც მგელი მას შეჭამს, ასევე ვერ დატოვებს ცხვარს და კომბოსტოს, 
რადგან ცხვარი შეჭამს კომბოსტოს.
'''
# როგორ უნდა გადაიყვანოს ფერმერმა თითოეული მათგანი ისე, 
# რომ ცხვარიც და კომბოსტოც შეუჭმელი დარჩეს?
'ამოხსნა'
'''
1 წაიყვანე ცხვარი
2 წამოდი მარტო
3 წაიყვანე მგელი
4 წამოიყვანე ცხვარი
5 წაიღე თივა; 
6 წამოდი მარტო 
7 წაიყვანე ცხვარი
'''
# თამაშის დაწყება
print('შენ გაქვს მხოლოდ 7 ცდა')
while True:
#     წასვლა
    print('ცდა პირველი')
    რომელი = input('რომელს წაიყვან? (მგელი/ცხვარი/თივა)')
#   წაიყვანოს ცხვარი
    if რომელი == 'ცხვარი':
#       წამოსვლა
        print('კარგად მიდიხარ, ცდა მეორე')
        print('უკან მოდიხარ')
        რომელი = input('რომელს წაიყვან? (ცხვარი/მარტო)')
#       წამოვიდეს მარტო
        if რომელი == 'მარტო':
#           წასვლა
            print('კარგად მიდიხარ, ცდა მესამე')
            რომელი = input ('რომელს წაიყვან? (მგელი/თივა)')
#           წაიყვანოს მგელი
            if რომელი=='მგელი':
                print('კარგად მიდიხარ, ცდა მეოთხე')
#               წამოიყვანოს ცხვარი
                print('უკან მოდიხარ')
                რომელი = input ('რომელს წაიყვან? (მგელი/ცხვარი)')                
                if რომელი =='ცხვარი':
                    print('კარგად მიდიხარ, ცდა მეხუთე')                
#                   წაიღოს თივა
                    რომელი = input ('რომელს წაიყვან? (ცხვარი/თივა)') 
                    if რომელი == "თივა":
                        print('კარგად მიდიხარ, ცდა მეექვსე')
                        print('უკან მოდიხარ')
#                      წამოიყვანოს
                        რომელი = input ('რომელს წაიყვან? (მგელი/მარტო)') 
                        if რომელი =='მარტო':
                            რომელი=input('ბოლო ცდა და ეგარი, რომელს წაიყვან? (მარტო/ცხვარი)')
                            if რომელი=='ცხვარი':
                                print('<><><><><><><><><><><><><>')
                                print('ყოჩაღ, ნაფიქრი გაქვს,\nმაგრამ ჩემი პასუხების გარეშე ვერ ამოხსნიდი')
                                break
                            else:
                                print('<><><><><><><><><><><><><>')
                                print('შენ გქონია ნერვი,თამაშის დედაცვატირე\nაღარ ითამაშო სუ არ გადაირიო')
                                break
                        else:
                            print('არგამოვიდა და წააგე.\nგარტყმით არ გააკეთო კარგად იფიქრე და ისე შეიყვანე')
                            continue          
                    else:           
                        print('არგამოვიდა და წააგე.\nგარტყმით არ გააკეთო კარგად იფიქრე და ისე შეიყვანე')
                        continue           
                else:           
                    print('არგამოვიდა და წააგე.\nგარტყმით არ გააკეთო კარგად იფიქრე და ისე შეიყვანე')
                    continue
            else:           
                print('არგამოვიდა და წააგე.\nგარტყმით არ გააკეთო კარგად იფიქრე და ისე შეიყვანე')
                continue
        else:           
            print('არგამოვიდა და წააგე.\nგარტყმით არ გააკეთო კარგად იფიქრე და ისე შეიყვანე')
            continue          
    else:
        print('არგამოვიდა და წააგე.\nგარტყმით არ გააკეთო კარგად იფიქრე და ისე შეიყვანე')
        continue
# Out:
# შენ გაქვს მხოლოდ 7 ცდა
# ცდა პირველი
